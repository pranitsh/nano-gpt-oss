# %% [markdown]
# ### Installing Important Libraries

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Begin Training
#
# Requires at least 14.5 gb of memory. Tested for 1 epoch on T4 GPU. Batch size is 1. Context length is 2000.

# %%
# Note: this also prepares the dataset
# !python train.py
